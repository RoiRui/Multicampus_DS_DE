# %% [markdown]
# ## 📂 DataFrame 인덱서 - loc
#
# DataFrame의 일반적인 인덱싱 방법은 열 우선이기 때문에 행 단위의 접근이 어렵다.<br>
# loc는 DataFrame의 인덱싱 방법 중 하나로 인덱스를 기준으로 행 단위의 데이터에 접근할 수 있다.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame(np.arange(10, 22).reshape(3,4),
                  index=['a', 'b', 'c'],
                  columns=['A', 'B', 'C', 'D'])
df1
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# 인덱서를 사용하지 않을 경우 DataFrame의 인덱싱은 열 우선이므로 아래와 같이 행 단독 인덱싱이 불가능하다.

# %%
try :
    df1['a']
except Exception as e :
    print(type(e))
# Out:
# <class 'KeyError'>

# %% [markdown]
# loc를 사용하면 다음과 같이 행 단독 인덱싱이 가능하다.

# %%
df1.loc['a']
# Out:
# A    10
# B    11
# C    12
# D    13
# Name: a, dtype: int32

# %% [markdown]
# 1개 이상의 인덱스명을 선택하고자 할 때에는 리스트를 사용한다.

# %%
df1.loc[['a']]
# Out:
#     A   B   C   D
# a  10  11  12  13

# %%
df1.loc[['b', 'c']]
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# 컬럼이 아닌 인덱스이므로 슬라이싱이 가능하다.

# %%
df1.loc['b':'c']
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# Boolean Selection으로 행을 선택할 수 있다.

# %%
df1.A > 15
# Out:
# a    False
# b    False
# c     True
# Name: A, dtype: bool

# %%
df1.loc[df1.A > 15]
# Out:
#     A   B   C   D
# c  18  19  20  21

# %% [markdown]
# 인덱스명과 컬럼명을 이용해 개별 데이터에 접근할 수 있다.

# %%
df1.loc['a', 'A']
# Out:
# 10

# %%
df1.loc['a', 'A'] = 50

# %%
df1
# Out:
#     A   B   C   D
# a  50  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# loc 인덱서를 사용해 다음과 같이 다양한 방법으로 인덱싱을 할 수 있다.

# %%
df1.loc['a']               # a 행의 모든 열 선택, Series 반환
df1.loc['a', 'B':'C']      # a 행의 B ~ C 열 선택, Series 반환
df1.loc['a']['B':'C']      # a 행의 B ~ C 열 선택, Series 반환
df1.loc['a', ['B', 'C']]   # a 행의 B, C 열 선택, Series 반환
df1.loc[['a']]             # a 행의 모든 열 선택, DataFrame 반환
df1.loc[['a'], 'B':'C']    # a 행의 B ~ C 열 선택, DataFrame 반환
df1.loc[['a'], ['B', 'C']] # a 행의 B, C 열 선택, DataFrame 반환
# Out:
# A    50
# B    11
# C    12
# D    13
# Name: a, dtype: int32
# B    11
# C    12
# Name: a, dtype: int32
# B    11
# C    12
# Name: a, dtype: int32
# B    11
# C    12
# Name: a, dtype: int32
#     A   B   C   D
# a  50  11  12  13
#     B   C
# a  11  12
#     B   C
# a  11  12

# %% [markdown]
# ---
#
# ## 📂 DataFrame 인덱서 - iloc
#
# loc와 동일하게 행 단위 접근을 지원하는 DataFrame 인덱서이다.<br>
# 그러나 인덱스명이 아닌 위치를 나타내는 정수 인덱스만을 사용한다.

# %%
df1
# Out:
#     A   B   C   D
# a  50  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# 인덱스 번호과 컬럼 번호을 선택해 개별 데이터에 접근할 수 있다.

# %%
df1.iloc[0, 1]
# Out:
# 11

# %% [markdown]
# 슬라이싱을 이용해 원하는 행과 열을 선택할 수 있다.

# %%
df1.iloc[0:2, 1:2]
# Out:
#     B
# a  11
# b  15

# %% [markdown]
# 단일 인덱스 번호 혹은 단일 컬럼 번호를 하나라도 포함한다면 반환형태는 Series이다.

# %%
df1.iloc[2]
# Out:
# A    18
# B    19
# C    20
# D    21
# Name: c, dtype: int32

# %%
df1.iloc[0:2, 1]
# Out:
# a    11
# b    15
# Name: B, dtype: int32

# %% [markdown]
# 1개 이상의 인덱스 번호 또는 컬럼 번호를 선택하고자 할 때에는 리스트를 사용한다.

# %%
df1.iloc[[0, 1], [1, 2]]
# Out:
#     B   C
# a  11  12
# b  15  16
